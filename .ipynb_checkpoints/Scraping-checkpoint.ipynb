# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from bs4 import *
import pandas as pd
from csv import writer
from time import sleep
import re
import csv
import collections
import sys
#install chrom webdriver
#webdriver can be downloaded from #https://chromedriver.storage.googleapis.com/index.html?path=94.0.4606.41/
#driver = webdriver.Chrome(executable_path='chromedriver.exe')


def beatstar():
    song=[] #List to store name of the product
    bpm=[] #List to store price of the product
    singer=[]
    empty = []
    genre=["POP", "HIP_HOP" ,"TRAP" ,"RNB" , "OLD_SCHOOL", "UNDERGROUND", "WEST_COAST"]
    for index in range(len(genre)):
        driver = webdriver.Chrome(executable_path='chromedriver.exe')
        sleep(2)
        driver.get("https://www.beatstars.com/search?type=tracks&genres="+genre[index])
        print("Browser closed")
        content = driver.page_source
        soup = BeautifulSoup(content)
        #sleep(randint(2,10))
        # print(soup)
        # list-item ng-star-inserted
        # item-title
        # name ng-star-inserted
        # name ng-star-inserted
        print("appending songs for" + genre[index])
        for a in soup.findAll('mp-card-figcaption-template',attrs={'class':'list-item'}):
            songs=a.find('a', attrs={'class':'ng-star-inserted'})
            beat=soup.find('span', attrs={'class':'name ng-star-inserted'})
            singers=soup.find('div', attrs={'class':'wrapper flex ng-star-inserted'})

            song.append(songs.text)
            bpm.append(beat.text)
            singer.append(singers.text)
        print (song)
        print("adding data to files")
        #ratings.append(rating.text)
        df = pd.DataFrame({'Songs Name':song , 'Genre': genre[index] , 'Beat per Minute': bpm , 'Singer' : singer })
        df.to_csv('songs.csv',mode='a' , index=False, encoding='utf-8')

def soundclick_hiphop():
    song_arr=[] #List to store name of the product
    bpm=[] #List to store price of the product
    singer=[]
    genre = []

    for page in range(20):
        driver = webdriver.Chrome(executable_path='chromedriver.exe')
        print("Browser opened")
        driver.get("https://www.soundclick.com/music/charts.cfm?genreID=19&currentPage="+str(page))
        print("Browser closed")  
        content = driver.page_source
        soup = BeautifulSoup(content)
        for a in soup.findAll('div',attrs={'class':'charts_titleBox'}):
            #songs = soup.find('div',attrs={'class':'charts_songname songActivityIndicator clk_loadPlaylist'})

            sleep(2)
            #songs = soup.find('div',attrs={'class':'charts_songname songActivityIndicator clk_loadPlaylist'})
            songs = soup.select_one("[id='charts_titleBox'] > span:nth-of-type(1000)")
            #songs=re.sub(' \n ',' ',(soup.find('span',attrs={'class':'charts_titleBox'}).getText())
            numbers = a.find('div', attrs={'class':'chartsPosition'})      
            singers = a.find('a', attrs={'class':'sclk_link'})
            s=a.get_text()
            song_arr.append(s)
            singer.append(singers.text)
            genre.append("Hip Hop")
            bpm.append(100)
            #print(song)
            
            
            df = pd.DataFrame({'Songs Name':song_arr , 'Genre': genre ,  'Beat per Minute': 100 , 'Singer' : singer })
            df.to_csv('songs.csv',mode='a' , index=False, encoding='utf-8')
#             with open('songs.csv', 'a') as f_object:
#                 writer_object = writer(f_object)
#                 writer_object.writerow(song)
#                 f_object.close()

def soundclick_acoustic():
    song_arr=[] #List to store name of the product
    bpm=[] #List to store price of the product
    singer=[]
    genre = []
    number = []
    for page in range(20):
        driver = webdriver.Chrome(executable_path='chromedriver.exe')
        print(" opening Browser")
        driver.get('https://www.soundclick.com/music/charts.cfm?genreID=1&currentPage='+str(page))
        sleep(2)
        content = driver.page_source
        soup = BeautifulSoup(content)
        for a in soup.findAll('div',attrs={'class':'charts_titleBox'}):
            #songs = soup.find('div',attrs={'class':'charts_songname songActivityIndicator clk_loadPlaylist'})
            songs = soup.select_one("[id='charts_titleBox'] > span:nth-of-type(1000)")
            #songs=re.sub(' \n ',' ',(soup.find('span',attrs={'class':'charts_titleBox'}).getText())
            numbers = a.find('div', attrs={'class':'chartsPosition'})      
            singers = a.find('a', attrs={'class':'sclk_link'})
            s=a.get_text()
            song_arr.append(s)
            print (song_arr)
            singer.append(singers.text)
            genre.append("Acoustic")
            bpm.append(100)
            number.append(numbers.text)
            df = pd.DataFrame({'Songs Name': song_arr , 'Genre': genre ,  'Beat per Minute': 100 , 'Singer' : singer })
            df.to_csv('songs.csv',mode='a' , index=False, encoding='utf-8')
beatstar()
soundclick_hiphop()
soundclick_acoustic()
print ("Check the csv file")
# Out:
# Browser closed
# appending songs forPOP
# [' Squid Game X Drill Type Beat - "Game" | Instru Rap Piano ', ' Meant | Guitar Boompin ', ' Delorean (80s, The Weeknd) ', ' Never Again | Sad Emotional Type Beat ', ' Cream ', ' Midnight - 80s Retro, The Weeknd Type Beat ', ' EXILE (Billie Eilish x Dark Pop Type Beat) ', ' Close ', ' Waiting For You (Emotional Piano Ballad Type Beat) ', ' Manic  -  Dark Billie Eilish Type Beat ', ' Paper People ', ' Free ', ' Broken ', ' Sirens  -  Billie Eilish Type Beat ', ' ghosted ', ' LIKKLE (UK AFROBEATS) prod LTTB ', ' NOCHE ', ' Miss Me | Sad Type Beat ', ' Fearless ', ' RIVER BALLAD (Billie Eilish x Olivia Rodrigo Sad Piano Beat) ', ' Too Much (BUY 1 GET 3 FREE) ', ' GEEKED (Trippie Redd x Drake x Playboi Carti Type Beat) ']
# adding data to files
# Browser closed
# appending songs forHIP_HOP
# [' Squid Game X Drill Type Beat - "Game" | Instru Rap Piano ', ' Meant | Guitar Boompin ', ' Delorean (80s, The Weeknd) ', ' Never Again | Sad Emotional Type Beat ', ' Cream ', ' Midnight - 80s Retro, The Weeknd Type Beat ', ' EXILE (Billie Eilish x Dark Pop Type Beat) ', ' Close ', ' Waiting For You (Emotional Piano Ballad Type Beat) ', ' Manic  -  Dark Billie Eilish Type Beat ', ' Paper People ', ' Free ', ' Broken ', ' Sirens  -  Billie Eilish Type Beat ', ' ghosted ', ' LIKKLE (UK AFROBEATS) prod LTTB ', ' NOCHE ', ' Miss Me | Sad Type Beat ', ' Fearless ', ' RIVER BALLAD (Billie Eilish x Olivia Rodrigo Sad Piano Beat) ', ' Too Much (BUY 1 GET 3 FREE) ', ' GEEKED (Trippie Redd x Drake x Playboi Carti Type Beat) ', ' 061 Street ', ' Meant | Guitar Boompin ', ' Audemars ', ' Lover boy Interlude 3 | BUY 2 GET 1 FREE ', ' Crossroads (Blues/Hip Hop) ', ' Intoxicated ', ' TRANSCEND | Beat Switch | Travis Scott Type Beat ', ' Pressure ', ' Models (BUY 2 GET 1 FREE) Key Glock x Pooh Shiesty Type Beat ', ' STARS ', ' Let Me ', ' Delorean (80s, The Weeknd) ', ' Never Die | Drake Type Beat ', ' Moshpit ', ' LV FRVR (DONDA KANYE WEST) ', ' SNOW IN MIAMI (STREET BANGER) ', ' Version ', ' Never Again | Sad Emotional Type Beat ', ' Phantom Of The Opera ', ' Lost voice ', ' Tables Turn [ R&B ] ( Buy 1 Get 1 Free ) ', ' Kanye West X Tyler The Creator X Baby Keem X JID Type Beat
', ' Kanye West X Tyler The Creator X Baby Keem X JID Type Beat ', ' 👻 Cult | Buy 2 Get 1 Free ', ' FOR THE PEOPLE ', ' Extra ', ' Trying To Make It Through ', ' Tyler The Creator X A$AP Rocky X Joey Badass Type Beat ', ' Most High ', ' J. Cole X Bas X Kendrick Lamar X Isaiah Rashad Type Beat ', ' "Betrayed" (Buy 1 Get 1 Free) ', ' URUS ', ' Stop Playin | Lil Baby x Meek Mill Type Beat ', ' Never Die | Drake Type Beat ', ' Pillow (Trap Soul, RnB, Summer Walker) ', ' SNOW IN MIAMI (STREET BANGER) ', ' Phantom Of The Opera ', ' Tables Turn [ R&B ] ( Buy 1 Get 1 Free ) ', ' Kanye West X Tyler The Creator X Baby Keem X JID Type Beat ', ' Boogie (Funk, Disco) ', ' Walls | Drake Vibe Type Beat ', ' HOLD ON ', ' Call My Name ', ' See U Cry | Drake Type Beat 2021 ', ' Candy (Chill, R&B) ', ' WASTING TIME - Rnb Type Beat ', ' J. Cole X Bas X Kendrick Lamar X Isaiah Rashad Type Beat ', ' Fall For You ', ' Toxic King ', ' Free ', ' LIE TO ME - Rnb type beat ', ' Flow ', ' Dreams Of Mine | Drake Type Beat ', ' Just Do It (Buy 2 Get 8 Free) ', ' Angel Wings | Buy 1 get 1 free ', ' LEARNING - Joey Badass Type Beat ', ' We Like That | Jadakiss x Jay Z Type Beat ', " Soulful Boom Bap Hip Hop Beat - 'Times' ", ' 1991 - Old School Boom Bap Beat ', ' Woman Like You ', ' Thinking ', ' Nocturne ', ' Harder Than Ever | Jay Z Type Beat ', ' TRANSITION - Isaiah Rashad x Mick Jenkins Type Beat ', ' Stupid ', ' Turpentine ', ' Smoke ', ' August ', ' Free Chill Soul Sample Old School Boom Bap 90s Type Beat ', ' Said and Done (Drake Type Beat) ', " Mac Miller Type Beat - 'Recollection' ", " Russ Type Beat - 'Without Me' ", ' Stranded ', ' No Time ', ' Die For This (w/hook) ', ' 🎃 HALLOWEEN OFFER 🎃 - Thriller (pt. 2) ', ' BREAK OUT [PROD BY JON DOE WONDER] ', ' SUPREME (STREET BANGER) ', ' Reflect ', ' COLD BLOODED (STREET BANGER) ', ' "Versace" 90s OldSchool Type Freestyle Beat ', ' "Behind Barz - Freestyle Rap Beat | Hard Boom Bap Type Beat ', ' PRAISES DUE (SOUL BANGER) ', ' KUSH (SOUL BANGER) ', ' Paradise | BUY 1 Get 1 FREE ', ' THE SHINING (SOUL BANGER) ', ' "Thinking of You" - Storytelling Boom Bap Instrumental ', ' Lost Marbles ', ' Formula ', ' "Mi Deseo" - Instrumental rap desahogo ', ' baby keem x kendr ...
# adding data to files
# Browser opened
# Browser closed
# Browser opened
# Browser closed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0c314c0e027b> in <module>
#     114             df.to_csv('songs.csv',mode='a' , index=False, encoding='utf-8')
#     115 beatstar()
# --> 116 soundclick_hiphop()
#     117 soundclick_acoustic()
#     118 print ("Check the csv file")
#
# <ipython-input-1-0c314c0e027b> in soundclick_hiphop()
#      78
#      79
# ---> 80             df = pd.DataFrame({'Songs Name':song , 'Genre': genre ,  'Beat per Minute': 100 , 'Singer' : singer })
#      81             df.to_csv('songs.csv',mode='a' , index=False, encoding='utf-8')
#      82 #             with open('songs.csv', 'a') as f_object:
#
# NameError: name 'song' is not defined
